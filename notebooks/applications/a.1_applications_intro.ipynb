# %% [markdown]
# # Further Applications
#
# The notebooks in this section demonstrate the use of FEniCS-SZ for other applications and publications:
#  * [Time-dependent coupling depth](codillo/a.c.1_sz_tdep_coupling.ipynb); Codillo et al., EPSL, submitted
